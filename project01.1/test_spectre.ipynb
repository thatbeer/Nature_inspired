# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from run import run_genetic_algorithm

# %%
x = "brazil"

# %%
x.split("_")[0]
# Out:
# 'brazil'

# %% [markdown]
# ### EXP01

# %%
burma_conf = './conf/burma01.yaml'
brazil_conf = './conf/brazil01.yaml'

conf = [burma_conf, brazil_conf]

for c in conf:
    run_genetic_algorithm(c)
# Out:
# d:\USERS\Exeter\Courses\Module ECMM409 (2023) Nature-Inspired Computation\Nature_inspired\project01.1\core\utils.py:20: RuntimeWarning: invalid value encountered in multiply
#   weights_metric = np.nan_to_num(np.identity(num_node) * -np.inf, 0.0)

# %%
import os

dst_path = os.path.abspath('dst')
burma = os.path.join(dst_path,'burma')
brazil = os.path.join(dst_path,'brazil')
file_name = "test_template.csv"

# %%
df1 = pd.read_csv(os.path.join(burma,file_name))
df2 = pd.read_csv(os.path.join(brazil,file_name))
df1.columns
# Out:
# Index(['trial', 'best_gene', 'best_fitness', 'avg_fitness', 'times'], dtype='object')

# %%
df1
# Out:
#      trial                                       best_gene  best_fitness  \
# 0        1  [12, 6, 11, 5, 4, 3, 2, 13, 1, 0, 9, 8, 10, 7]      0.000301
# 1        2  [2, 13, 1, 0, 9, 8, 10, 7, 12, 6, 11, 5, 4, 3]      0.000301
# 2        3  [5, 11, 6, 12, 7, 0, 10, 8, 9, 1, 13, 2, 3, 4]      0.000297
# 3        4  [11, 5, 4, 3, 2, 13, 1, 9, 8, 10, 0, 7, 12, 6]      0.000297
# 4        5  [2, 13, 11, 5, 3, 4, 6, 12, 7, 10, 8, 9, 0, 1]      0.000284
# ..     ...                                             ...           ...
# 995    996  [2, 13, 11, 5, 3, 4, 6, 12, 10, 8, 9, 7, 0, 1]      0.000283
# 996    997  [7, 9, 8, 10, 12, 6, 11, 5, 4, 3, 2, 13, 1, 0]      0.000300
# 997    998  [4, 3, 2, 13, 1, 0, 7, 9, 8, 10, 12, 6, 5, 11]      0.000298
# 998    999  [3, 2, 1, 0, 7, 8, 9, 10, 12, 6, 13, 11, 5, 4]      0.000287
# 999   1000  [5, 6, 12, 8, 9, 10, 7, 0, 1, 13, 2, 3, 4, 11]      0.000294
#
#      avg_fitness     times
# 0       0.000301  0.279996
# 1       0.000301  0.153034
# ...

# %%
df1['best_fitness'].idxmax()
# Out:
# 18

# %%
df1.iloc[18,:]
# Out:
# trial                                                       19
# best_gene       [2, 13, 1, 0, 9, 8, 10, 7, 12, 6, 11, 5, 4, 3]
# best_fitness                                          0.000301
# avg_fitness                                           0.000301
# times                                                 0.250988
# Name: 18, dtype: object

# %%
1/0.000301
# Out:
# 3322.2591362126245

# %%
df2
# Out:
#      trial                                          best_gene  best_fitness  \
# 0        1  [21, 46, 2, 9, 48, 16, 25, 20, 10, 14, 45, 33,...      0.000017
# 1        2  [38, 26, 57, 54, 37, 41, 25, 51, 40, 50, 36, 3...      0.000015
# 2        3  [29, 24, 0, 39, 3, 15, 6, 37, 54, 34, 20, 27, ...      0.000015
# 3        4  [19, 24, 12, 23, 52, 53, 22, 4, 32, 55, 44, 33...      0.000016
# 4        5  [28, 23, 49, 12, 17, 19, 24, 3, 22, 50, 1, 51,...      0.000015
# ..     ...                                                ...           ...
# 995    996  [17, 22, 54, 9, 1, 39, 23, 12, 38, 50, 51, 4, ...      0.000016
# 996    997  [53, 37, 21, 7, 54, 51, 57, 43, 11, 5, 14, 27,...      0.000015
# 997    998  [33, 14, 35, 50, 22, 4, 7, 5, 55, 20, 9, 2, 57...      0.000017
# 998    999  [53, 22, 25, 47, 28, 35, 40, 48, 46, 8, 3, 19,...      0.000015
# 999   1000  [36, 32, 13, 51, 48, 26, 11, 24, 12, 23, 22, 3...      0.000017
#
#      avg_fitness     times
# 0       0.000017  0.361845
# ...

# %%
fig , ax = plt.subplots(2,2,sharex=True,sharey=False,figsize=(10,10))
ax[0][0].plot(df1.trial,df1.best_fitness)
ax[0][1].plot(df2.trial,df2.best_fitness)
ax[1][0].plot(df1.trial,df1.avg_fitness)
ax[1][1].plot(df2.trial,df2.avg_fitness)

# %%
sns.lineplot(x=df1.trial,y=df1.times)
# sns.lineplot(x=df1.trial,y=df1.avg_fitness)
# Out:
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.lineplot(x=df2.trial,y=df2.best_fitness)
sns.lineplot(x=df2.trial,y=df2.avg_fitness)
# Out:
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### EXP02

# %%
burma_conf = './conf/burma02.yaml'
brazil_conf = './conf/brazil02.yaml'

conf = [burma_conf, brazil_conf]

for c in conf:
    run_genetic_algorithm(c)
# Out:
# d:\USERS\Exeter\Courses\Module ECMM409 (2023) Nature-Inspired Computation\Nature_inspired\project01.1\core\utils.py:20: RuntimeWarning: invalid value encountered in multiply
#   weights_metric = np.nan_to_num(np.identity(num_node) * -np.inf, 0.0)

# %%
file_name = "exp02.csv"
df1 = pd.read_csv(os.path.join(burma,file_name))
df2 = pd.read_csv(os.path.join(brazil,file_name))
df1.columns
# Out:
# Index(['trial', 'best_gene', 'best_fitness', 'avg_fitness', 'times'], dtype='object')

# %%
fig , ax = plt.subplots(2,2,sharex=True,sharey=False)
ax[0][0].plot(df1.trial,df1.best_fitness)
ax[0][1].plot(df1.trial,df1.best_fitness)
ax[1][0].plot(df2.trial,df2.avg_fitness)
ax[1][1].plot(df2.trial,df2.avg_fitness)

# %%
ax[1]
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
df2.max()
# Out:
# trial                                                         100
# best_gene       [8, 39, 24, 3, 19, 31, 52, 43, 0, 17, 22, 49, ...
# best_fitness                                             0.000024
# avg_fitness                                              0.000023
# times                                                    0.684002
# dtype: object

# %%
1/0.000024
# Out:
# 41666.666666666664
