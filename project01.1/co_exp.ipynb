# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from core.search import search_trail, search_sole , trial_plot , gens_plot
from core.utils import create_config

# %%
# baseline for the whole experiment
parameters_data = {
    "max_generations": 1000,
    "population_size": 100,
    "tournament_size": 10,
    "p_select": 1.0,
    "p_crossover": 1.0,
    "p_mutate": 1.0,
}
functions_data = {
    "crossover_fn": "point_crossover", # point_crossover, partialmap_crossover, ordered_crossover
    "mutate_fn": "inversion", #mutate(1swap), inversion, scramble, mutli_mutate
    "replace_fn": "replace_weakest",
}
cfg = create_config(
    name="test_template",
    path="./data/burma14.xml", 
    file_name="burma_test0101",
    num_trial=20, # ignored by Sole_Exp
    parameters=parameters_data, 
    functions=functions_data)

# %% [markdown]
# test1 : crossover with single point

# %%
functions_data = {
    "crossover_fn": "point_crossover", # point_crossover, partialmap_crossover, ordered_crossover
    "mutate_fn": "inversion", #mutate(1swap), inversion, scramble, mutli_mutate
    "replace_fn": "replace_weakest",
}

cfg = create_config(
    name="test_crossover01",
    path="./data/burma14.xml", 
    file_name="burma_crossover01",
    num_trial=20, # ignored by Sole_Exp
    parameters=parameters_data, 
    functions=functions_data)

cfg2 = create_config(
    name="test_mutate01",
    path="./data/brazil58.xml", 
    file_name="burma_crossover01",
    num_trial=20, # ignored by Sole_Exp, used by search_trial
    parameters=parameters_data, 
    functions=functions_data)

df01 = search_trail(cfg)
df02 = search_trail(cfg2)
gf01 = search_sole(cfg)
gf02 = search_sole(cfg2)

# %%
df01.to_csv('./cs_resources/burma_test1.csv')
df02.to_csv('./cs_resources/brazil_test1.csv')
gf01.to_csv('./cs_resources/burma_gent1.csv')
gf02.to_csv('./cs_resources/brazil_gent1.csv')

# %%
print(df01.mean())
print(df01.std())
# Out:
# Trial                 10.500000
# Time                   0.499597
# Best_fitness           0.000298
# Avg_fitness            0.000287
# Gen100        Best     0.000247
#               Avg      0.000209
# Gen300        Best     0.000283
#               Avg      0.000252
# Gen500        Best     0.000291
#               Avg      0.000270
# Gen1000       Best     0.000298
#               Avg      0.000287
# dtype: float64
# Trial                 5.916080
# Time                  0.277170
# Best_fitness          0.000005
# Avg_fitness           0.000006
# Gen100        Best    0.000010
#               Avg     0.000007
# Gen300        Best    0.000009
#               Avg     0.000008
# Gen500        Best    0.000008
#               Avg     0.000007
# Gen1000       Best    0.000005
#               Avg     0.000006
# dtype: float64

# %%
print(df02.mean())
print(df02.std())
# Out:
# Trial                 10.500000
# Time                   0.666359
# Best_fitness           0.000021
# Avg_fitness            0.000020
# Gen100        Best     0.000012
#               Avg      0.000011
# Gen300        Best     0.000015
#               Avg      0.000014
# Gen500        Best     0.000017
#               Avg      0.000016
# Gen1000       Best     0.000021
#               Avg      0.000020
# dtype: float64
# Trial                 5.916080e+00
# Time                  4.984601e-02
# Best_fitness          1.287344e-06
# Avg_fitness           9.446249e-07
# Gen100        Best    6.579540e-07
#               Avg     4.838441e-07
# Gen300        Best    7.896964e-07
#               Avg     7.627788e-07
# Gen500        Best    8.918353e-07
#               Avg     7.812703e-07
# Gen1000       Best    1.287344e-06
#               Avg     9.446249e-07
# dtype: float64

# %%
gf01 = search_sole(cfg)
gf02 = search_sole(cfg2)

# %%
gf01
# Out:
#      gens  best_fitness  avg_fitness  \
# 0       1      0.000194     0.000152
# 1       2      0.000194     0.000153
# 2       3      0.000194     0.000154
# 3       4      0.000194     0.000155
# 4       5      0.000194     0.000155
# ..    ...           ...          ...
# 995   996      0.000301     0.000290
# 996   997      0.000301     0.000290
# 997   998      0.000301     0.000290
# 998   999      0.000301     0.000290
# 999  1000      0.000301     0.000290
#
#                                           best_gene
# 0    [10, 5, 4, 3, 0, 8, 7, 1, 2, 6, 11, 13, 12, 9]
# 1    [10, 5, 4, 3, 0, 8, 7, 1, 2, 6, 11, 13, 12, 9]
# 2    [10, 5, 4, 3, 0, 8, 7, 1, 2, 6, 11, 13, 12, 9]
# 3    [10, 5, 4, 3, 0, 8, 7, 1, 2, 6, 11, 13, 12, 9]
# 4    [10, 5, 4, 3, 0, 8, 7, 1, 2, 6, 11, 13, 12, 9]
# ..                                              ...
# 995  [12, 6, 11, 5, 4, 3, 2, 13, 1, 0, 9, 8, 10, 7]
# 996  [12, 6, 11, 5, 4, 3, 2, 13, 1, 0, 9, 8, 10, 7]
# ...

# %%
gens_plot(gf01)

# %%
gens_plot(gf02)

# %%
df01.set_index('Trial')
# Out:
#            Time Best_fitness Avg_fitness    Gen100              Gen300  \
#                                               Best       Avg      Best
# Trial
# 1      1.393556     0.000300    0.000289  0.000240  0.000210  0.000273
# 2      0.792005     0.000301    0.000286  0.000250  0.000210  0.000285
# 3      0.585999     0.000301    0.000291  0.000268  0.000217  0.000282
# 4      0.804997     0.000301    0.000289  0.000257  0.000212  0.000287
# 5      0.752998     0.000300    0.000292  0.000242  0.000205  0.000287
# 6      0.664011     0.000301    0.000282  0.000247  0.000206  0.000277
# 7      0.584989     0.000297    0.000288  0.000240  0.000212  0.000295
# 8      0.481016     0.000300    0.000285  0.000239  0.000210  0.000276
# 9      0.458983     0.000300    0.000291  0.000241  0.000201  0.000295
# 10     0.327013     0.000301    0.000289  0.000259  0.000220  0.000285
# 11     0.324021     0.000301    0.000296  0.000248  0.000210  0.000300
# ...

# %%
trial_plot(df01)

# %%
df02
# Out:
#    Trial      Time Best_fitness Avg_fitness    Gen100              Gen300  \
#                                                  Best       Avg      Best
# 0      1  0.747037     0.000021    0.000020  0.000012  0.000011  0.000015
# 1      2  0.751956     0.000022    0.000020  0.000012  0.000011  0.000014
# 2      3  0.636041     0.000024    0.000022  0.000012  0.000010  0.000014
# 3      4  0.637038     0.000022    0.000020  0.000011  0.000010  0.000016
# 4      5  0.753042     0.000022    0.000020  0.000011  0.000010  0.000014
# 5      6  0.680027     0.000021    0.000020  0.000013  0.000011  0.000015
# 6      7  0.609002     0.000020    0.000019  0.000013  0.000012  0.000016
# 7      8  0.657997     0.000021    0.000020  0.000013  0.000011  0.000016
# 8      9  0.631002     0.000022    0.000021  0.000012  0.000011  0.000015
# 9     10  0.656999     0.000020    0.000019  0.000011  0.000010  0.000014
# 10    11  0.638024     0.000019    0.000018  0.000013  0.000011  0.000015
# ...

# %%
trial_plot(df02)

# %%
print("_____BURMA_______")
print(df01.Gen500.mean(),df01.Gen500.std())
print(df01.Gen1000.mean(),df01.Gen1000.std())
print(df01.Time.mean(),df01.Time.std())
print("_____BRAZIL_______")
print(df02.Gen500.mean(),df02.Gen500.std())
print(df02.Gen1000.mean(),df02.Gen1000.std())
print(df02.Time.mean(),df02.Time.std())
# Out:
# _____BURMA_______
# Best    0.000291
# Avg     0.000270
# dtype: float64 Best    0.000008
# Avg     0.000007
# dtype: float64
# Best    0.000298
# Avg     0.000287
# dtype: float64 Best    0.000005
# Avg     0.000006
# dtype: float64
# 0.4995974779129028 0.277170232422973
# _____BRAZIL_______
# Best    0.000017
# Avg     0.000016
# dtype: float64 Best    8.918353e-07
# Avg     7.812703e-07
# dtype: float64
# Best    0.000021
# Avg     0.000020
# dtype: float64 Best    1.287344e-06
# Avg     9.446249e-07
# dtype: float64
# 0.6663592100143433 0.04984600657367145

# %% [markdown]
# test 2 : partialmap_crossover

# %%
functions_data = {
    "crossover_fn": "partialmap_crossover", # point_crossover, partialmap_crossover, ordered_crossover
    "mutate_fn": "inversion", #mutate(1swap), inversion, scramble, mutli_mutate
    "replace_fn": "replace_weakest",
}

cfg = create_config(
    name="test_crossover21",
    path="./data/burma14.xml", 
    file_name="burma_crossover21",
    num_trial=20, # ignored by Sole_Exp
    parameters=parameters_data, 
    functions=functions_data)

cfg2 = create_config(
    name="test_crossover21",
    path="./data/brazil58.xml", 
    file_name="burma_crossover21",
    num_trial=20, # ignored by Sole_Exp, used by search_trial
    parameters=parameters_data, 
    functions=functions_data)

df11 = search_trail(cfg)
df12 = search_trail(cfg2)
gf11 = search_sole(cfg)
gf12 = search_sole(cfg2)

# %%
df11.to_csv('./cs_resources/burma_test2.csv')
df12.to_csv('./cs_resources/brazil_test2.csv')
gf11.to_csv('./cs_resources/burma_gent2.csv')
gf12.to_csv('./cs_resources/brazil_gent2.csv')

# %%
print(df11.mean())
print(df11.std())
# Out:
# Trial                 10.500000
# Time                   0.344856
# Best_fitness           0.000299
# Avg_fitness            0.000286
# Gen100        Best     0.000252
#               Avg      0.000204
# Gen300        Best     0.000282
#               Avg      0.000250
# Gen500        Best     0.000293
#               Avg      0.000268
# Gen1000       Best     0.000299
#               Avg      0.000286
# dtype: float64
# Trial                 5.916080
# Time                  0.035729
# Best_fitness          0.000003
# Avg_fitness           0.000004
# Gen100        Best    0.000015
#               Avg     0.000009
# Gen300        Best    0.000010
#               Avg     0.000011
# Gen500        Best    0.000007
#               Avg     0.000009
# Gen1000       Best    0.000003
#               Avg     0.000004
# dtype: float64

# %%
print(df12.mean())
print(df12.std())
# Out:
# Trial                 10.500000
# Time                   0.699622
# Best_fitness           0.000020
# Avg_fitness            0.000019
# Gen100        Best     0.000012
#               Avg      0.000010
# Gen300        Best     0.000015
#               Avg      0.000013
# Gen500        Best     0.000016
#               Avg      0.000015
# Gen1000       Best     0.000020
#               Avg      0.000019
# dtype: float64
# Trial                 5.916080e+00
# Time                  3.341065e-02
# Best_fitness          1.510890e-06
# Avg_fitness           1.339377e-06
# Gen100        Best    5.222687e-07
#               Avg     3.333316e-07
# Gen300        Best    5.740631e-07
#               Avg     5.061834e-07
# Gen500        Best    8.969912e-07
#               Avg     7.511115e-07
# Gen1000       Best    1.510890e-06
#               Avg     1.339377e-06
# dtype: float64

# %%
gens_plot(gf11)

# %%
gens_plot(gf12)

# %%
df11
# Out:
#    Trial      Time Best_fitness Avg_fitness    Gen100              Gen300  \
#                                                  Best       Avg      Best
# 0      1  0.361040     0.000301    0.000290  0.000268  0.000220  0.000287
# 1      2  0.359979     0.000301    0.000280  0.000242  0.000197  0.000256
# 2      3  0.482002     0.000298    0.000288  0.000242  0.000197  0.000285
# 3      4  0.343049     0.000300    0.000283  0.000241  0.000203  0.000269
# 4      5  0.342964     0.000290    0.000282  0.000268  0.000210  0.000278
# 5      6  0.358985     0.000301    0.000286  0.000239  0.000195  0.000281
# 6      7  0.334051     0.000299    0.000287  0.000225  0.000193  0.000289
# 7      8  0.316994     0.000301    0.000288  0.000258  0.000203  0.000288
# 8      9  0.313970     0.000300    0.000292  0.000257  0.000196  0.000298
# 9     10  0.337031     0.000301    0.000286  0.000253  0.000211  0.000270
# 10    11  0.347034     0.000290    0.000276  0.000230  0.000189  0.000282
# ...

# %%
trial_plot(df11)

# %%
df12
# Out:
#    Trial      Time Best_fitness Avg_fitness    Gen100              Gen300  \
#                                                  Best       Avg      Best
# 0      1  0.679042     0.000021    0.000020  0.000013  0.000011  0.000016
# 1      2  0.697969     0.000019    0.000017  0.000012  0.000011  0.000015
# 2      3  0.723323     0.000019    0.000018  0.000012  0.000010  0.000014
# 3      4  0.684005     0.000021    0.000019  0.000012  0.000011  0.000014
# 4      5  0.681000     0.000021    0.000020  0.000011  0.000010  0.000014
# 5      6  0.683033     0.000018    0.000017  0.000011  0.000010  0.000014
# 6      7  0.667998     0.000019    0.000018  0.000012  0.000011  0.000016
# 7      8  0.724954     0.000021    0.000019  0.000013  0.000011  0.000015
# 8      9  0.765010     0.000022    0.000019  0.000011  0.000010  0.000014
# 9     10  0.689002     0.000021    0.000020  0.000012  0.000010  0.000014
# 10    11  0.792995     0.000018    0.000018  0.000012  0.000010  0.000014
# ...

# %%
trial_plot(df12)

# %% [markdown]
# test 3 : ordered crossover

# %%
functions_data = {
    "crossover_fn": "ordered_crossover", # point_crossover, partialmap_crossover, ordered_crossover
    "mutate_fn": "inversion", #mutate(1swap), inversion, scramble, mutli_mutate
    "replace_fn": "replace_weakest",
}

cfg = create_config(
    name="test_crossover31",
    path="./data/burma14.xml", 
    file_name="burma_crossover31",
    num_trial=20, # ignored by Sole_Exp
    parameters=parameters_data, 
    functions=functions_data)

cfg2 = create_config(
    name="test_crossover31",
    path="./data/brazil58.xml", 
    file_name="burma_crossover31",
    num_trial=20, # ignored by Sole_Exp, used by search_trial
    parameters=parameters_data, 
    functions=functions_data)

df21 = search_trail(cfg)
df22 = search_trail(cfg2)
gf21 = search_sole(cfg)
gf22 = search_sole(cfg2)

# %%
df21.to_csv('./cs_resources/burma_test3.csv')
df22.to_csv('./cs_resources/brazil_test3.csv')
gf21.to_csv('./cs_resources/burma_gent3.csv')
gf22.to_csv('./cs_resources/brazil_gent3.csv')

# %%
print(df21.mean())
print(df21.std())
# Out:
# Trial                 10.500000
# Time                   0.340050
# Best_fitness           0.000300
# Avg_fitness            0.000288
# Gen100        Best     0.000249
#               Avg      0.000207
# Gen300        Best     0.000284
#               Avg      0.000250
# Gen500        Best     0.000296
#               Avg      0.000269
# Gen1000       Best     0.000300
#               Avg      0.000288
# dtype: float64
# Trial                 5.916080
# Time                  0.028378
# Best_fitness          0.000001
# Avg_fitness           0.000003
# Gen100        Best    0.000013
#               Avg     0.000005
# Gen300        Best    0.000011
#               Avg     0.000008
# Gen500        Best    0.000004
#               Avg     0.000007
# Gen1000       Best    0.000001
#               Avg     0.000003
# dtype: float64

# %%
print(df22.mean())
print(df22.std())
# Out:
# Trial                 10.500000
# Time                   0.700151
# Best_fitness           0.000021
# Avg_fitness            0.000019
# Gen100        Best     0.000012
#               Avg      0.000011
# Gen300        Best     0.000015
#               Avg      0.000013
# Gen500        Best     0.000017
#               Avg      0.000016
# Gen1000       Best     0.000021
#               Avg      0.000019
# dtype: float64
# Trial                 5.916080e+00
# Time                  4.774717e-02
# Best_fitness          1.181360e-06
# Avg_fitness           1.016295e-06
# Gen100        Best    7.551147e-07
#               Avg     3.958888e-07
# Gen300        Best    9.156255e-07
#               Avg     8.281432e-07
# Gen500        Best    9.237099e-07
#               Avg     9.312737e-07
# Gen1000       Best    1.181360e-06
#               Avg     1.016295e-06
# dtype: float64

# %%
gf21 = search_sole(cfg)
gf22 = search_sole(cfg2)

# %%
sns.lineplot(data=gf21,x='gens',y='best_fitness')
sns.lineplot(data=gf21,x='gens',y='avg_fitness')
# Out:
# <Axes: xlabel='gens', ylabel='best_fitness'>

# %%
gens_plot(gf21)

# %%
gens_plot(gf22)

# %%
df21
# Out:
#    Trial      Time Best_fitness Avg_fitness    Gen100              Gen300  \
#                                                  Best       Avg      Best
# 0      1  0.364973     0.000301    0.000290  0.000258  0.000211  0.000295
# 1      2  0.326985     0.000301    0.000283  0.000263  0.000207  0.000276
# 2      3  0.321004     0.000300    0.000293  0.000253  0.000212  0.000300
# 3      4  0.340041     0.000301    0.000295  0.000249  0.000209  0.000300
# 4      5  0.318030     0.000300    0.000287  0.000245  0.000209  0.000272
# 5      6  0.310032     0.000301    0.000289  0.000218  0.000194  0.000260
# 6      7  0.315970     0.000297    0.000290  0.000259  0.000211  0.000283
# 7      8  0.304030     0.000301    0.000287  0.000250  0.000205  0.000280
# 8      9  0.310963     0.000300    0.000281  0.000243  0.000207  0.000277
# 9     10  0.310993     0.000301    0.000291  0.000253  0.000210  0.000288
# 10    11  0.313010     0.000301    0.000285  0.000262  0.000207  0.000285
# ...

# %%
trial_plot(df21)

# %%
df22
# Out:
#    Trial      Time Best_fitness Avg_fitness    Gen100              Gen300  \
#                                                  Best       Avg      Best
# 0      1  0.740983     0.000022    0.000020  0.000011  0.000010  0.000014
# 1      2  0.754997     0.000021    0.000020  0.000011  0.000011  0.000015
# 2      3  0.745007     0.000020    0.000019  0.000012  0.000011  0.000015
# 3      4  0.851009     0.000019    0.000018  0.000011  0.000010  0.000013
# 4      5  0.688984     0.000021    0.000019  0.000011  0.000010  0.000014
# 5      6  0.659015     0.000019    0.000018  0.000011  0.000010  0.000015
# 6      7  0.667985     0.000020    0.000019  0.000011  0.000010  0.000015
# 7      8  0.693048     0.000022    0.000020  0.000012  0.000011  0.000016
# 8      9  0.677965     0.000023    0.000020  0.000014  0.000011  0.000017
# 9     10  0.744987     0.000022    0.000020  0.000013  0.000011  0.000016
# 10    11  0.670047     0.000019    0.000018  0.000012  0.000011  0.000015
# ...

# %%
trial_plot(df22)

# %% [markdown]
# # test with changed mutate function

# %%
functions_data = {
    "crossover_fn": "ordered_crossover", # point_crossover, partialmap_crossover, ordered_crossover
    "mutate_fn": "scramble", #mutate(1swap), inversion, scramble, mutli_mutate
    "replace_fn": "replace_weakest",
}

parameters_data = {
    "max_generations": 1000,
    "population_size": 500,
    "tournament_size": 400,
    "p_select": 1.0,
    "p_crossover": 1.0,
    "p_mutate": 1.0,
}

cfg = create_config(
    name="test_crossover31",
    path="./data/burma14.xml", 
    file_name="burma_crossover31",
    num_trial=30, # ignored by Sole_Exp
    parameters=parameters_data, 
    functions=functions_data)

cfg2 = create_config(
    name="test_crossover31",
    path="./data/brazil58.xml", 
    file_name="burma_crossover31",
    num_trial=30, # ignored by Sole_Exp, used by search_trial
    parameters=parameters_data, 
    functions=functions_data)

df31 = search_trail(cfg)
df32 = search_trail(cfg2)
gf31 = search_sole(cfg)
gf32 = search_sole(cfg2)

# %%
print(df31.mean())
print(df31.std())
# Out:
# Trial                 15.500000
# Time                   3.217639
# Best_fitness           0.000281
# Avg_fitness            0.000271
# Gen100        Best     0.000262
#               Avg      0.000179
# Gen300        Best     0.000278
#               Avg      0.000226
# Gen500        Best     0.000279
#               Avg      0.000251
# Gen1000       Best     0.000281
#               Avg      0.000271
# dtype: float64
# Trial                 8.803408
# Time                  0.174117
# Best_fitness          0.000014
# Avg_fitness           0.000013
# Gen100        Best    0.000015
#               Avg     0.000004
# Gen300        Best    0.000014
#               Avg     0.000009
# Gen500        Best    0.000014
#               Avg     0.000010
# Gen1000       Best    0.000014
#               Avg     0.000013
# dtype: float64

# %%
print(df32.mean())
print(df32.std())
# Out:
# Trial                 15.500000
# Time                   3.382119
# Best_fitness           0.000015
# Avg_fitness            0.000014
# Gen100        Best     0.000012
#               Avg      0.000009
# Gen300        Best     0.000013
#               Avg      0.000011
# Gen500        Best     0.000014
#               Avg      0.000012
# Gen1000       Best     0.000015
#               Avg      0.000014
# dtype: float64
# Trial                 8.803408e+00
# Time                  1.279270e-01
# Best_fitness          1.012949e-06
# Avg_fitness           7.354553e-07
# Gen100        Best    5.130564e-07
#               Avg     9.447950e-08
# Gen300        Best    6.327680e-07
#               Avg     2.937928e-07
# Gen500        Best    8.028019e-07
#               Avg     4.594137e-07
# Gen1000       Best    1.012949e-06
#               Avg     7.354553e-07
# dtype: float64

# %%
gens_plot(gf31)
gens_plot(gf32)
trial_plot(df31)
trial_plot(df32)

# %%
functions_data = {
    "crossover_fn": "ordered_crossover", # point_crossover, partialmap_crossover, ordered_crossover
    "mutate_fn": "inversion", #mutate(1swap), inversion, scramble, mutli_mutate
    "replace_fn": "replace_weakest",
}

parameters_data = {
    "max_generations": 1000,
    "population_size": 500,
    "tournament_size": 400,
    "p_select": 1.0,
    "p_crossover": 1.0,
    "p_mutate": 1.0,
}

cfg = create_config(
    name="test_crossover31",
    path="./data/burma14.xml", 
    file_name="burma_crossover31",
    num_trial=20, # ignored by Sole_Exp
    parameters=parameters_data, 
    functions=functions_data)

cfg2 = create_config(
    name="test_crossover31",
    path="./data/brazil58.xml", 
    file_name="burma_crossover31",
    num_trial=20, # ignored by Sole_Exp, used by search_trial
    parameters=parameters_data, 
    functions=functions_data)

df41 = search_trail(cfg)
df42 = search_trail(cfg2)
gf41 = search_sole(cfg)
gf42 = search_sole(cfg2)

gens_plot(gf41)
gens_plot(gf42)
trial_plot(df41)
trial_plot(df42)

# %%
print(df41.mean())
print(df41.std())
# Out:
# Trial                 10.500000
# Time                   4.335213
# Best_fitness           0.000298
# Avg_fitness            0.000277
# Gen100        Best     0.000283
#               Avg      0.000187
# Gen300        Best     0.000294
#               Avg      0.000242
# Gen500        Best     0.000295
#               Avg      0.000260
# Gen1000       Best     0.000298
#               Avg      0.000277
# dtype: float64
# Trial                 5.916080
# Time                  0.953295
# Best_fitness          0.000004
# Avg_fitness           0.000004
# Gen100        Best    0.000010
#               Avg     0.000002
# Gen300        Best    0.000008
#               Avg     0.000004
# Gen500        Best    0.000007
#               Avg     0.000005
# Gen1000       Best    0.000004
#               Avg     0.000004
# dtype: float64

# %%
print(df42.mean())
print(df42.std())
# Out:
# Trial                 10.500000
# Time                   5.364396
# Best_fitness           0.000029
# Avg_fitness            0.000026
# Gen100        Best     0.000015
#               Avg      0.000010
# Gen300        Best     0.000020
#               Avg      0.000016
# Gen500        Best     0.000023
#               Avg      0.000020
# Gen1000       Best     0.000029
#               Avg      0.000026
# dtype: float64
# Trial                 5.916080e+00
# Time                  3.667896e-01
# Best_fitness          1.257678e-06
# Avg_fitness           1.175396e-06
# Gen100        Best    1.310532e-06
#               Avg     2.434927e-07
# Gen300        Best    1.162688e-06
#               Avg     1.002509e-06
# Gen500        Best    1.210940e-06
#               Avg     9.217615e-07
# Gen1000       Best    1.257678e-06
#               Avg     1.175396e-06
# dtype: float64
