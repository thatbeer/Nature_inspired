# %%
from core.classes import SoleExp
from core.utils import load_yaml
from run_sole import search_sole

import pandas as pd
import seaborn as sns
import warnings
# Set the style and enable the grid
sns.set(style="whitegrid")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
path = './conf/burma08.yaml'

df = search_sole(path=path)
# Out:
# d:\USERS\Exeter\Courses\Module ECMM409 (2023) Nature-Inspired Computation\Nature_inspired\project01.1\core\utils.py:20: RuntimeWarning: invalid value encountered in multiply
#   weights_metric = np.nan_to_num(np.identity(num_node) * -np.inf, 0.0)

# %%
df
# Out:
#      gens  best_fitness  avg_fitness  \
# 0       1      0.000231     0.000151
# 1       2      0.000231     0.000152
# 2       3      0.000231     0.000153
# 3       4      0.000231     0.000153
# 4       5      0.000231     0.000154
# ..    ...           ...          ...
# 995   996      0.000276     0.000276
# 996   997      0.000276     0.000276
# 997   998      0.000276     0.000276
# 998   999      0.000276     0.000276
# 999  1000      0.000276     0.000276
#
#                                           best_gene
# 0    [13, 4, 5, 3, 2, 10, 9, 8, 0, 1, 7, 6, 12, 11]
# 1    [13, 4, 5, 3, 2, 10, 9, 8, 0, 1, 7, 6, 12, 11]
# 2    [13, 4, 5, 3, 2, 10, 9, 8, 0, 1, 7, 6, 12, 11]
# 3    [13, 4, 5, 3, 2, 10, 9, 8, 0, 1, 7, 6, 12, 11]
# 4    [13, 4, 5, 3, 2, 10, 9, 8, 0, 1, 7, 6, 12, 11]
# ..                                              ...
# 995  [3, 4, 5, 13, 2, 1, 0, 10, 8, 9, 7, 12, 6, 11]
# 996  [3, 4, 5, 13, 2, 1, 0, 10, 8, 9, 7, 12, 6, 11]
# ...

# %%
sns.lineplot( df.best_fitness, color='red',label='high')
sns.lineplot(df.avg_fitness,color='green',label='average')
# Out:
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
path = './conf/brazil02.yaml'

df2 = search_sole(path=path)

sns.lineplot( df2.best_fitness, color='red',label='high')
sns.lineplot(df2.avg_fitness,color='green',label='average')
# Out:
# d:\USERS\Exeter\Courses\Module ECMM409 (2023) Nature-Inspired Computation\Nature_inspired\project01.1\core\utils.py:20: RuntimeWarning: invalid value encountered in multiply
#   weights_metric = np.nan_to_num(np.identity(num_node) * -np.inf, 0.0)
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df2
# Out:
#      gens  best_fitness  avg_fitness  \
# 0       1      0.000010     0.000008
# 1       2      0.000010     0.000008
# 2       3      0.000010     0.000008
# 3       4      0.000010     0.000008
# 4       5      0.000010     0.000008
# ..    ...           ...          ...
# 995   996      0.000019     0.000019
# 996   997      0.000019     0.000019
# 997   998      0.000019     0.000019
# 998   999      0.000019     0.000019
# 999  1000      0.000019     0.000019
#
#                                              best_gene
# 0    [57, 48, 20, 28, 2, 22, 21, 31, 44, 54, 40, 4,...
# 1    [57, 48, 20, 28, 2, 22, 21, 31, 44, 54, 40, 4,...
# 2    [57, 48, 20, 28, 2, 22, 21, 31, 44, 54, 40, 4,...
# 3    [57, 26, 2, 5, 31, 23, 38, 13, 52, 40, 12, 45,...
# 4    [57, 26, 2, 5, 31, 23, 38, 13, 52, 40, 12, 45,...
# ..                                                 ...
# 995  [57, 23, 21, 7, 53, 51, 28, 38, 4, 0, 29, 49, ...
# 996  [57, 23, 21, 7, 53, 51, 28, 38, 4, 0, 29, 49, ...
# ...

# %%
path = './conf/burma03.yaml'

df3 = search_sole(path=path)

sns.lineplot( df3.best_fitness, color='red',label='high')
sns.lineplot(df3.avg_fitness,color='green',label='average')
# Out:
# d:\USERS\Exeter\Courses\Module ECMM409 (2023) Nature-Inspired Computation\Nature_inspired\project01.1\core\utils.py:20: RuntimeWarning: invalid value encountered in multiply
#   weights_metric = np.nan_to_num(np.identity(num_node) * -np.inf, 0.0)
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
path = './conf/brazil03.yaml'

df4 = search_sole(path=path)

sns.lineplot( df4.best_fitness, color='red',label='high')
sns.lineplot(df4.avg_fitness,color='green',label='average')
# Out:
# d:\USERS\Exeter\Courses\Module ECMM409 (2023) Nature-Inspired Computation\Nature_inspired\project01.1\core\utils.py:20: RuntimeWarning: invalid value encountered in multiply
#   weights_metric = np.nan_to_num(np.identity(num_node) * -np.inf, 0.0)
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\USER\anaconda3\envs\exeter\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
